# %%
import tensorflow
from keras.applications.resnet50 import ResNet50, preprocess_input
from keras.layers import MaxPooling2D

# %%
model = ResNet50(weights = 'imagenet', include_top = False, input_shape = (224, 224, 3))
model.trainable = False

# %%
model = tensorflow.keras.Sequential([model, MaxPooling2D()])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)           │ (None, 7, 7, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 3, 3, 2048)     │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,587,712 (89.98 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %%
import cv2
import numpy as np
from numpy.linalg import norm

# %%
img = cv2.imread(r'D:\Real Estate\E_commerce_Product\Dataset\10037.jpg')
img = cv2.resize(img, (224, 224))

# %%
cv2.imshow("Frame", img)
cv2.waitKey(0)
# Out:
# -1

# %%
img = np.array(img)

# %%
img.shape
# Out:
# (224, 224, 3)

# %%
# number  of image , 224, 224, 3
expand_img = np.expand_dims(img, axis = 0)

# %%
expand_img.shape
# Out:
# (1, 224, 224, 3)

# %%
pre_img = preprocess_input(expand_img)

# %%
pre_img.shape
# Out:
# (1, 224, 224, 3)

# %%
result = model.predict(pre_img).flatten()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step

# %%
Normalized = result/norm(result)

# %%
Normalized.shape
# Out:
# (18432,)

# %%
def extract_feature(img_path, model):
    img = cv2.imread(img_path)
    img = cv2.resize(img, (224, 224))
    img = np.array(img)
    expand_img = np.expand_dims(img, axis = 0)
    pre_img = preprocess_input(expand_img)
    result = model.predict(pre_img).flatten()
    normalized = result/norm(result)
    return normalized

# %%
extract_feature(r'D:\Real Estate\E_commerce_Product\Dataset\10037.jpg', model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# array([0.        , 0.        , 0.        , ..., 0.00211288, 0.        ,
#        0.01906054], dtype=float32)

# %%
import os

# %%
filename = []
feature_list = []
for file in os.listdir('Dataset'):
    filename.append(os.path.join('Dataset', file))

# %%
filename
# Out:
# ['Dataset\\10037.jpg',
#  'Dataset\\10039.jpg',
#  'Dataset\\10054.jpg',
#  'Dataset\\10096.jpg',
#  'Dataset\\10097.jpg',
#  'Dataset\\10110.jpg',
#  'Dataset\\10174.jpg',
#  'Dataset\\10180.jpg',
#  'Dataset\\10266.jpg',
#  'Dataset\\10267.jpg',
#  'Dataset\\10268.jpg',
#  'Dataset\\10269.jpg',
#  'Dataset\\10292.jpg',
#  'Dataset\\10293.jpg',
#  'Dataset\\10294.jpg',
#  'Dataset\\10295.jpg',
#  'Dataset\\10307.jpg',
#  'Dataset\\10309.jpg',
#  'Dataset\\10632.jpg',
#  'Dataset\\10633.jpg',
#  'Dataset\\10634.jpg',
#  'Dataset\\10635.jpg',
#  'Dataset\\10649.jpg',
#  'Dataset\\10671.jpg',
#  'Dataset\\10672.jpg',
#  'Dataset\\10755.jpg',
#  'Dataset\\11496.jpg',
#  'Dataset\\11497.jpg',
#  'Dataset\\11498.jpg',
#  'Dataset\\11499.jpg',
#  'Dataset\\11510.jpg',
#  'Dataset\\11511.jpg',
#  'Dataset\\11516.jpg',
#  'Dataset\\11517.jpg',
#  'Dataset\\11518.jpg',
#  'Dataset\\11519.jpg',
#  'Dataset\\11851.jpg',
#  'Dataset\\11856.jpg',
#  'Dataset\\11912.jpg',
#  'Dataset\\11913.jpg',
# ...

# %%
filename[0:5]
# Out:
# ['Dataset\\10037.jpg',
#  'Dataset\\10039.jpg',
#  'Dataset\\10054.jpg',
#  'Dataset\\10096.jpg',
#  'Dataset\\10097.jpg']

# %%
from tqdm import tqdm

# %%
for file in tqdm(filename):
    feature_list.append(extract_feature(file, model))
# Out:
#   0%|                                                                                                                                                                   | 0/2906 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
#   0%|                                                                                                                                                           | 1/2906 [00:00<07:03,  6.86it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
#   0%|                                                                                                                                                           | 2/2906 [00:00<07:28,  6.47it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
#   0%|▏                                                                                                                                                          | 3/2906 [00:00<07:40,  6.30it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# ...

# %%
import pickle

# %%
# pickle.dump(feature_list.open('featurevector.pkl', 'wb'))
# pickle.dump(filename.open('filenames.pkl', 'wb'))

# %%
# Save `feature_list` to a file named 'featurevector.pkl'
with open('featurevector.pkl', 'wb') as f:
    pickle.dump(feature_list, f)

# Save `filename` to a file named 'filenames.pkl'
with open('filenames.pkl', 'wb') as f:
    pickle.dump(filename, f)

print("Files saved successfully.")
# Out:
# Files saved successfully.
